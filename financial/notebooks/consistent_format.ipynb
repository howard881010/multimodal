# %%
{
    "Key numbers": "",
    "Growth trends": "",
    "Market outlook": "",
    "Notable copmany-specific news": "",
    "Overall summary": ""
}
# Out:
# {'Key numbers': '',
#  'Growth trends': '',
#  'Market outlook': '',
#  'Notable copmany-specific news': '',
#  'Overall summary': ''}

# %%
import pandas as pd
from glob import glob

# %%
paths = sorted(glob('/data/kai/forecasting/data/summary_v0.2 copy/*'))
print(paths)

for path in paths:
    path = paths[0]
    df = pd.read_csv(path)
    try:
        df.drop(columns=["Unnamed: 0"], inplace=True)
        df.to_csv(path, index=False)
    except KeyError:
        continue
# Out:
# ['/data/kai/forecasting/data/summary_v0.2 copy/AAPL.csv', '/data/kai/forecasting/data/summary_v0.2 copy/ABBV.csv', '/data/kai/forecasting/data/summary_v0.2 copy/AMD.csv', '/data/kai/forecasting/data/summary_v0.2 copy/AMZN.csv', '/data/kai/forecasting/data/summary_v0.2 copy/AVGO.csv', '/data/kai/forecasting/data/summary_v0.2 copy/COST.csv', '/data/kai/forecasting/data/summary_v0.2 copy/CRM.csv', '/data/kai/forecasting/data/summary_v0.2 copy/CVX.csv', '/data/kai/forecasting/data/summary_v0.2 copy/GOOG.csv', '/data/kai/forecasting/data/summary_v0.2 copy/HD.csv', '/data/kai/forecasting/data/summary_v0.2 copy/JNJ.csv', '/data/kai/forecasting/data/summary_v0.2 copy/LLY.csv', '/data/kai/forecasting/data/summary_v0.2 copy/MA.csv', '/data/kai/forecasting/data/summary_v0.2 copy/META.csv', '/data/kai/forecasting/data/summary_v0.2 copy/MSFT.csv', '/data/kai/forecasting/data/summary_v0.2 copy/NFLX.csv', '/data/kai/forecasting/data/summary_v0.2 copy/NVDA.csv', '/data/kai/forecasting/data/summary_v
# ...

# %%
df
# Out:
#         timestamp ticker                                                url  \
# 0      2022-03-01   AAPL  https://www.aljazeera.com/economy/2022/3/1/us-...
# 1      2022-03-02   AAPL  https://www.scmp.com/tech/big-tech/article/316...
# 2      2022-03-02   AAPL  https://www.cnn.com/2022/03/02/business/russia...
# 3      2022-03-02   AAPL  https://www.aljazeera.com/economy/2022/3/2/ric...
# 4      2022-03-03   AAPL  https://www.investors.com/market-trend/stock-m...
# ...           ...    ...                                                ...
# 17415  2024-04-29   AAPL  https://www.zacks.com/stock/news/2264427/will-...
# 17416  2024-04-29   AAPL  https://www.benzinga.com/news/earnings/24/04/3...
# 17417  2024-04-29   AAPL  https://www.zacks.com/commentary/2264463/apple...
# 17418  2024-04-29   AAPL  https://www.kiplinger.com/investing/stocks/sto...
# 17419  2024-04-29   AAPL  https://www.investors.com/market-trend/stock-m...
#
# ...
